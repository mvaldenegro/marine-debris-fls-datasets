# %%
# DeepLabV3 architecture with various encoders
# Output stride = 8 (so vary the encoder architecture accordingly)
import tensorflow as tf
import numpy as np
import os

# %%
# mount google drive here
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataPath  = '/content/drive/My Drive/Underwater_Segmentation_Research/Data'

trainPath       =  dataPath + '/Train'
testPath        =  dataPath + '/Test'
valPath         =  dataPath + '/Validate'

trainImgsFile   = 'trainingDataImgs.npy'
trainLabelsFile = 'trainingDataLabels.npy'

testImgsFile    = 'testingDataImgs.npy'
testLabelsFile  = 'testingDataLabels.npy'

valImgsFile     = 'validationDataImgs.npy'
valLabelsFile   = 'validationDataLabels.npy'

testImgs = None
testLabels = None


def getData(path,fileName):
  return np.load(path + "/" + fileName)

trainImgs   = getData(trainPath, trainImgsFile)
trainLabels = getData(trainPath, trainLabelsFile)

valImgs    = getData(valPath, valImgsFile)
valLabels  = getData(valPath, valLabelsFile)

print("Got train and validation data")
print(trainImgs.shape, valImgs.shape)
print(trainLabels.shape, valLabels.shape)
# Out:
# Got train and validation data
# (1000, 480, 320, 1) (251, 480, 320, 1)
# (1000, 480, 320, 1) (251, 480, 320, 1)

# %%
class UpdatedMeanIoU(tf.keras.metrics.MeanIoU):
  def __init__(self,
               y_true=None,
               y_pred=None,
               num_classes=None,
               name=None,
               dtype=None):
    super(UpdatedMeanIoU, self).__init__(num_classes = num_classes,name=name, dtype=dtype)

  def update_state(self, y_true, y_pred, sample_weight=None):
    y_pred = tf.math.argmax(y_pred, axis=-1)
    return super().update_state(y_true, y_pred, sample_weight)

# %%
vgg19 = tf.keras.applications.VGG19(include_top=False, weights=None, input_tensor=None, input_shape=(480,320,1))

# %%
print(vgg19.summary())
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 480, 320, 1)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 480, 320, 64)      640
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 480, 320, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 240, 160, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 240, 160, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 240, 160, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 120, 80, 128)      0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 120, 80, 256)      295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 120, 80, 256)      590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 120, 80, 256)      590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 120, 80, 256)      590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 60, 40, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 60, 40, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 60, 40, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 60, 40, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 60, 40, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 30, 20, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 30, 20, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 30, 20, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 30, 20, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 30, 20, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 15, 10, 512)       0
# =================================================================
# Total params: 20,023,232
# Trainable params: 20,023,232
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#vgg16 = tf.keras.applications.VGG16(include_top=False, weights=None, input_tensor=None, input_shape=(480,320,1))

# layer after which changes related to deeplabv3 architecture are made
layerName = 'block4_conv4'

# get the output of this layer and then add new layers after this
block4_conv3 = vgg19.get_layer(layerName).output
block4_pool = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=1, name='block4_pool', padding='same')(block4_conv3)

# block 5 with Atrous Convolution with rate=2 and maxPooling with stride=1
block5_atrConv1 = tf.keras.layers.Conv2D(512, (3,3), strides=1, dilation_rate=2, padding='same', activation='relu', name='block5_atrConv1')(block4_pool)
block5_atrConv2 = tf.keras.layers.Conv2D(512, (3,3), strides=1, dilation_rate=2, padding='same', activation='relu', name='block5_atrConv2')(block5_atrConv1)
block5_atrConv3 = tf.keras.layers.Conv2D(512, (3,3), strides=1, dilation_rate=2, padding='same', activation='relu', name='block5_atrConv3')(block5_atrConv2)
block5_atrConv4 = tf.keras.layers.Conv2D(512, (3,3), strides=1, dilation_rate=2, padding='same', activation='relu', name='block5_atrConv4')(block5_atrConv3)
block5_pool     = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=1, name='block5_pool', padding='same')(block5_atrConv4)

# Now add the ASPP module
# For that -> create 5 branches -> b0 (conv1x1+relu+bn)256
#                               -> b1 (conv3x3+relu+rate_12 +bn)256
#                               -> b2 (conv3x3 + relu + rate_24 + bn)256
#                               -> b3 (conv3x3 + relu + rate_24 + bn)256
#                               -> b4 (globalAvgPool -> Conv1x1 + relu -> BN + upsample)256
# Then concat all -> apply 1x1 conv 256 + relu + bn -> conv 1x1 12 -> softmax -> bilinear upsampling

output_stride=8

bn_axis=3

b0 = tf.keras.layers.Conv2D(256, (1,1), activation='relu', padding='same', name='aspp_b0')(block5_pool)
b0_BN = tf.keras.layers.BatchNormalization(axis=bn_axis, name='aspp_b0_BN')(b0)

b1 = tf.keras.layers.Conv2D(256, (3,3), dilation_rate=12, activation='relu', padding='same', name='aspp_b1')(block5_pool)
b1_BN = tf.keras.layers.BatchNormalization(axis=bn_axis, name='aspp_b1_BN')(b1)

b2 = tf.keras.layers.Conv2D(256, (3,3), dilation_rate=24, activation='relu', padding='same', name='aspp_b2')(block5_pool)
b2_BN = tf.keras.layers.BatchNormalization(axis=bn_axis, name='aspp_b2_BN')(b2)

b3 = tf.keras.layers.Conv2D(256, (3,3), dilation_rate=36, activation='relu', padding='same', name='aspp_b3')(block5_pool)
b3_BN = tf.keras.layers.BatchNormalization(axis=bn_axis, name='aspp_b3_BN')(b3)

b4 = tf.keras.layers.Conv2D(256, (1,1), activation='relu', padding='same', name='aspp_b4_conv')(tf.keras.layers.AveragePooling2D(name='aspp_b4')(block5_pool))
b4_BN = tf.keras.layers.BatchNormalization(axis=bn_axis, name='aspp_b4_BN')(b4)
b4_up = tf.keras.layers.UpSampling2D(size=(2,2), name='aspp_b4_upsample')(b4_BN)

# now concatenate these outputs
aspp = tf.keras.layers.Concatenate(axis=bn_axis, name='aspp_concatenate')([b0_BN, b1_BN, b2_BN, b4_up])

asppOut_conv1 = tf.keras.layers.Conv2D(256, (1,1), activation='relu', padding='same', name='asppOut_conv1')(aspp)
asppOut_BN    = tf.keras.layers.BatchNormalization(axis=bn_axis, name='asppOut_BN')(asppOut_conv1)

out_small = tf.keras.layers.Conv2D(12, (1,1), activation='softmax', padding='same', name='out_small')(asppOut_BN)
out       = tf.keras.layers.UpSampling2D(size=(8,8), name='output')(out_small)

model = tf.keras.Model(vgg19.input, out)
print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 480, 320, 1) 0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 480, 320, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 480, 320, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 240, 160, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 240, 160, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 240, 160, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 120, 80, 128) 0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 120, 80, 256) 295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 120, 80, 256) 590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 120, 80, 256) 590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv4 (Conv2D)           (None, 120, 80, 256) 590080      block3_conv3[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 60, 40, 256)  0           block3_conv4[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 60, 40, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 60, 40, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 60, 40, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_conv4 (Conv2D)           (None, 60, 40, 512)  2359808     block4_conv3[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 60, 40, 512)  0           block4_conv4[0][0]
# __________________________________________________________________________________________________
# block5_atrConv1 (Conv2D)        (None, 60, 40, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_atrConv2 (Conv2D)        (None, 60, 40, 512)  2359808     block5_atrConv1[0][0]
# __________________________________________________________________________________________________
# block5_atrConv3 (Conv2D)        (None, 60, 40, 512)  2359808     block5_atrConv2[0][0]
# __________________________________________________________________________________________________
# block5_atrConv4 (Conv2D)        (None, 60, 40, 512)  2359808     block5_atrConv3[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 60, 40, 512)  0           block5_atrConv4[0][0]
# __________________________________________________________________________________________________
# aspp_b4 (AveragePooling2D)      (None, 30, 20, 512)  0           block5_pool[0][0]
# __________________________________________________________________________________________________
# aspp_b4_conv (Conv2D)           (None, 30, 20, 256)  131328      aspp_b4[0][0]
# __________________________________________________________________________________________________
# aspp_b0 (Conv2D)                (None, 60, 40, 256)  131328      block5_pool[0][0]
# __________________________________________________________________________________________________
# aspp_b1 (Conv2D)                (None, 60, 40, 256)  1179904     block5_pool[0][0]
# __________________________________________________________________________________________________
# aspp_b2 (Conv2D)                (None, 60, 40, 256)  1179904     block5_pool[0][0]
# __________________________________________________________________________________________________
# aspp_b4_BN (BatchNormalization) (None, 30, 20, 256)  1024        aspp_b4_conv[0][0]
# __________________________________________________________________________________________________
# aspp_b0_BN (BatchNormalization) (None, 60, 40, 256)  1024        aspp_b0[0][0]
# __________________________________________________________________________________________________
# aspp_b1_BN (BatchNormalization) (None, 60, 40, 256)  1024        aspp_b1[0][0]
# __________________________________________________________________________________________________
# aspp_b2_BN (BatchNormalization) (None, 60, 40, 256)  1024        aspp_b2[0][0]
# __________________________________________________________________________________________________
# aspp_b4_upsample (UpSampling2D) (None, 60, 40, 256)  0           aspp_b4_BN[0][0]
# __________________________________________________________________________________________________
# aspp_concatenate (Concatenate)  (None, 60, 40, 1024) 0           aspp_b0_BN[0][0]
#                                                                  aspp_b1_BN[0][0]
#                                                                  aspp_b2_BN[0][0]
#                                                                  aspp_b4_upsample[0][0]
# __________________________________________________________________________________________________
# asppOut_conv1 (Conv2D)          (None, 60, 40, 256)  262400      aspp_concatenate[0][0]
# __________________________________________________________________________________________________
# asppOut_BN (BatchNormalization) (None, 60, 40, 256)  1024        asppOut_conv1[0][0]
# __________________________________________________________________________________________________
# out_small (Conv2D)              (None, 60, 40, 12)   3084        asppOut_BN[0][0]
# __________________________________________________________________________________________________
# output (UpSampling2D)           (None, 480, 320, 12) 0           out_small[0][0]
# ==================================================================================================
# Total params: 22,916,300
# Trainable params: 22,913,740
# Non-trainable params: 2,560
# __________________________________________________________________________________________________
# None

# %%
tf.keras.utils.plot_model(model)

# %%
import tensorflow as tf
LOSS=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model.compile('Adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy', UpdatedMeanIoU(num_classes=12)])

# %%
# Setup training parameters
BATCH = 16
EPOCHS = 30

# early stopping callback. It stops training when the loss does not change for 3 consecutive epochs
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
history = model.fit(trainImgs, trainLabels, epochs=EPOCHS, batch_size=BATCH, validation_data=(valImgs, valLabels))
# Out:
# Epoch 1/30
# 63/63 [==============================] - 171s 2s/step - loss: 1.8001 - accuracy: 0.7395 - updated_mean_io_u: 0.0842 - val_loss: 4.4612 - val_accuracy: 0.3182 - val_updated_mean_io_u: 0.0321
# Epoch 2/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.3674 - accuracy: 0.9646 - updated_mean_io_u: 0.1247 - val_loss: 0.2244 - val_accuracy: 0.9632 - val_updated_mean_io_u: 0.0863
# Epoch 3/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.1559 - accuracy: 0.9692 - updated_mean_io_u: 0.1372 - val_loss: 0.2662 - val_accuracy: 0.9283 - val_updated_mean_io_u: 0.1223
# Epoch 4/30
# 63/63 [==============================] - 87s 1s/step - loss: 0.1256 - accuracy: 0.9701 - updated_mean_io_u: 0.1572 - val_loss: 0.1552 - val_accuracy: 0.9643 - val_updated_mean_io_u: 0.1627
# Epoch 5/30
# 63/63 [==============================] - 87s 1s/step - loss: 0.1033 - accuracy: 0.9722 - updated_mean_io_u: 0.2003 - val_loss: 0.1758 - val_accuracy: 0.9622 - val_updated_mean_io_u: 0.0804
# Epoch 6/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0888 - accuracy: 0.9745 - updated_mean_io_u: 0.2556 - val_loss: 0.1387 - val_accuracy: 0.9643 - val_updated_mean_io_u: 0.0919
# Epoch 7/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0765 - accuracy: 0.9769 - updated_mean_io_u: 0.3054 - val_loss: 0.2009 - val_accuracy: 0.9632 - val_updated_mean_io_u: 0.0854
# Epoch 8/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0664 - accuracy: 0.9786 - updated_mean_io_u: 0.3569 - val_loss: 0.3181 - val_accuracy: 0.9613 - val_updated_mean_io_u: 0.0801
# Epoch 9/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0650 - accuracy: 0.9788 - updated_mean_io_u: 0.3736 - val_loss: 0.1285 - val_accuracy: 0.9661 - val_updated_mean_io_u: 0.1122
# Epoch 10/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0593 - accuracy: 0.9801 - updated_mean_io_u: 0.4135 - val_loss: 0.1039 - val_accuracy: 0.9697 - val_updated_mean_io_u: 0.1472
# Epoch 11/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0531 - accuracy: 0.9814 - updated_mean_io_u: 0.4568 - val_loss: 0.1815 - val_accuracy: 0.9622 - val_updated_mean_io_u: 0.0885
# Epoch 12/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0485 - accuracy: 0.9828 - updated_mean_io_u: 0.4887 - val_loss: 0.0542 - val_accuracy: 0.9827 - val_updated_mean_io_u: 0.4302
# Epoch 13/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0471 - accuracy: 0.9831 - updated_mean_io_u: 0.5071 - val_loss: 0.0605 - val_accuracy: 0.9808 - val_updated_mean_io_u: 0.5027
# Epoch 14/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0438 - accuracy: 0.9839 - updated_mean_io_u: 0.5323 - val_loss: 0.0608 - val_accuracy: 0.9807 - val_updated_mean_io_u: 0.3242
# Epoch 15/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0427 - accuracy: 0.9841 - updated_mean_io_u: 0.5503 - val_loss: 0.0473 - val_accuracy: 0.9842 - val_updated_mean_io_u: 0.5241
# Epoch 16/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0418 - accuracy: 0.9844 - updated_mean_io_u: 0.5540 - val_loss: 0.0630 - val_accuracy: 0.9815 - val_updated_mean_io_u: 0.5510
# Epoch 17/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0402 - accuracy: 0.9849 - updated_mean_io_u: 0.5772 - val_loss: 0.0712 - val_accuracy: 0.9787 - val_updated_mean_io_u: 0.5281
# Epoch 18/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0427 - accuracy: 0.9839 - updated_mean_io_u: 0.5479 - val_loss: 0.0635 - val_accuracy: 0.9807 - val_updated_mean_io_u: 0.3891
# Epoch 19/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0409 - accuracy: 0.9845 - updated_mean_io_u: 0.5597 - val_loss: 0.0625 - val_accuracy: 0.9803 - val_updated_mean_io_u: 0.5594
# Epoch 20/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0377 - accuracy: 0.9854 - updated_mean_io_u: 0.5901 - val_loss: 0.0496 - val_accuracy: 0.9834 - val_updated_mean_io_u: 0.5966
# Epoch 21/30
# 63/63 [==============================] - 89s 1s/step - loss: 0.0362 - accuracy: 0.9859 - updated_mean_io_u: 0.6032 - val_loss: 0.0448 - val_accuracy: 0.9854 - val_updated_mean_io_u: 0.5986
# Epoch 22/30
# 63/63 [==============================] - 89s 1s/step - loss: 0.0356 - accuracy: 0.9861 - updated_mean_io_u: 0.6102 - val_loss: 0.0537 - val_accuracy: 0.9832 - val_updated_mean_io_u: 0.6000
# Epoch 23/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0352 - accuracy: 0.9862 - updated_mean_io_u: 0.6184 - val_loss: 0.0874 - val_accuracy: 0.9740 - val_updated_mean_io_u: 0.5171
# Epoch 24/30
# 63/63 [==============================] - 89s 1s/step - loss: 0.0353 - accuracy: 0.9863 - updated_mean_io_u: 0.6155 - val_loss: 0.0885 - val_accuracy: 0.9738 - val_updated_mean_io_u: 0.4922
# Epoch 25/30
# 63/63 [==============================] - 90s 1s/step - loss: 0.0355 - accuracy: 0.9860 - updated_mean_io_u: 0.6095 - val_loss: 0.0812 - val_accuracy: 0.9766 - val_updated_mean_io_u: 0.5644
# Epoch 26/30
# 63/63 [==============================] - 89s 1s/step - loss: 0.0334 - accuracy: 0.9867 - updated_mean_io_u: 0.6279 - val_loss: 0.0470 - val_accuracy: 0.9844 - val_updated_mean_io_u: 0.6228
# Epoch 27/30
# 63/63 [==============================] - 89s 1s/step - loss: 0.0325 - accuracy: 0.9868 - updated_mean_io_u: 0.6320 - val_loss: 0.0670 - val_accuracy: 0.9801 - val_updated_mean_io_u: 0.5913
# Epoch 28/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0323 - accuracy: 0.9871 - updated_mean_io_u: 0.6356 - val_loss: 0.0404 - val_accuracy: 0.9864 - val_updated_mean_io_u: 0.6350
# Epoch 29/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0327 - accuracy: 0.9869 - updated_mean_io_u: 0.6330 - val_loss: 0.0700 - val_accuracy: 0.9806 - val_updated_mean_io_u: 0.5709
# Epoch 30/30
# 63/63 [==============================] - 86s 1s/step - loss: 0.0326 - accuracy: 0.9869 - updated_mean_io_u: 0.6314 - val_loss: 0.0405 - val_accuracy: 0.9863 - val_updated_mean_io_u: 0.6285

# %%
#  Plot the results
print(history.history.keys())

import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
# Out:
# dict_keys(['loss', 'accuracy', 'updated_mean_io_u', 'val_loss', 'val_accuracy', 'val_updated_mean_io_u'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['updated_mean_io_u'])
plt.plot(history.history['val_updated_mean_io_u'])

# %%
# get the testdata
testImgs   = getData(testPath, testImgsFile)
testLabels = getData(testPath, testLabelsFile)

# %%
model.evaluate(testImgs, testLabels)
# Out:
# 20/20 [==============================] - 42s 1s/step - loss: 0.0364 - accuracy: 0.9865 - updated_mean_io_u: 0.6406
# [0.03642137721180916, 0.9864612221717834, 0.6405977606773376]

# %%
# save the model weights
weightFileName = 'DeepLabV3VggNet19_30e_16b.h5'
weightPath = '/content/drive/My Drive/Underwater_Segmentation_Research/Weights/DeepLabV3'
model.save_weights(weightPath + "/" + weightFileName)

# %%
modelFileName = "DeepLabV3VggNet19_30e_16b"
modelPath     = '/content/drive/My Drive/Underwater_Segmentation_Research/Models/DeepLabV3'
model.save(modelPath + "/" + modelFileName)
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Underwater_Segmentation_Research/Models/DeepLabV3/DeepLabV3VggNet19_30e_16b/assets

# %%
# Check the GPU configuration
# !nvidia-smi
# Out:
# Fri Jun 11 18:02:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P0    34W /  70W |  14570MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
y_preds = model.predict(testImgs)
y_preds = (y_preds >= 0.5).astype(np.uint8)

# %%
yPreds = tf.argmax(y_preds, axis=-1)
yPreds = yPreds.numpy()

# %%
# Compute mean of per-class IOU throughout the test images
num_classes=12
m = UpdatedMeanIoU(num_classes=12)
m.update_state(testLabels, y_preds)

print(f'Overall mean IOU is : {m.result().numpy()}')

# Values is the confusion matrix
values = np.array(m.get_weights()).reshape(num_classes, num_classes)

# %%
# compute the mean per-class IOU
numClasses = 12

classIOU = []

for i in range(numClasses):
  rowSum = np.sum(values[i,:])
  colSum = np.sum(values[:,i])
  denom = rowSum + colSum - values[i,i]
  iou = values[i,i]/denom
  classIOU.append(iou)

print(classIOU)
perClassIoU = np.array(classIOU)
print(np.mean(perClassIoU))

# %%
import matplotlib.pyplot as plt
i = 0
plt.imshow(yPreds[i])
plt.show()

print(np.unique(yPreds[i,:,:]))

plt.imshow(testLabels[i,:,:,0])
plt.show()

print(np.unique(testLabels[i,:,:,0]))

t = np.linspace(0,11,num=12)
plt.plot(t, perClassIoU)
plt.show()
